# %%
import time

from IPython.display import Markdown, display  # Import
from openai import OpenAI
import warnings
import tiktoken
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec
import os
from dotenv import load_dotenv
from src.embeddings import *
from src.data_processing import *

warnings.filterwarnings("ignore")
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
pinecone_api_key = os.getenv("PINECONE_API_KEY")

# %% [markdown]
# ## Load Index

# %%
pc = Pinecone(pinecone_api_key)
index = pc.Index("legal-assistant-rag")
index.describe_index_stats()
# Out:
# {'dimension': 3072,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 13660}},
#  'total_vector_count': 13660}

# %% [markdown]
# ## Query

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
query = "What are the main business requirements for Regulation O?"
xq = client.embeddings.create(input=query, model="text-embedding-3-large").data[0].embedding
res = index.query(vector=xq, top_k=20, include_metadata=True)
res
# Out:
# {'matches': [{'id': '10661',
#               'metadata': {'content': 'Each executive officer or director of a '
#                                       'member bank the shares of \n'
#                                       'which are not publicly traded shall '
#                                       'report annually to the board of \n'
#                                       'directors of the member bank the '
#                                       'outstanding amount of any credit that \n'
#                                       'was extended to the executive officer '
#                                       'or director and that is secured by \n'
#                                       'shares of the member bank.\n'
#                                       '\n'
#                                       '[Reg. O, 59 FR 8837, Feb. 24, 1994. '
#                                       'Redesignated at 71 FR 71474, Dec. \n'
#                                       '11, 2006]\n'
#                                       '\n'
#                                       '\n'
#                                       '<R05>\n'
#                                       'Sec.  215.11  Civil penalties.\n'
#                                       '\n'
#                                       '    Any member bank, or any officer, '
#                                       'director, employee, agent, or other \n'
#                                       'person participating in the conduct of '
#                                       'the affairs of the bank, that \n'
#                                       'violates any provision of this part '
#                                       '(other than Sec.  215.9) is subject \n'
#                                       'to civil penalties as specified in '
#                                       'section 29 of the Federal Reserve Act \n'
#                                       '(12 U.S.C. 504).\n'
#                                       '\n'
#                                       '[Reg. O, 71 FR 71475, Dec. 11, 2006]\n'
#                                       '\n'
#                                       '\n'
#                                       '<R05>\n'
#                                       'Sec.  215.12  Application to savings '
#                                       'associations.\n'
#                                       '\n'
#                                       '    The requirements of this part apply '
#                                       'to savings associations, as \n'
#                                       'defined in 12 CFR 238.2(l) (including '
#                                       'any subsidiary of a savings \n'
#                                       'association), in the same\n'
#                                       '\n'
#                                       '[[Page 405]]\n'
#                                       '\n'
#                                       'manner and to the same extent as if the '
#                                       'savings association were a \n'
#                                       'member bank; provided that a savings '
#                                       "association's unimpaired capital \n"
#                                       'and unimpaired surplus will be '
#                                       'determined under regulatory capital '
#                                       'rules \n'
#                                       'applicable to that savings '
#                                       'association.\n'
#                                       '\n'
#                                       '[Reg. O, 76 FR 56530, Sept. 13, 2011]\n'
#                                       '\n'
#                                       '\n'
#                                       '<R05>\n'
#                                       ' Sec. Appendix to Part 215--Section '
#                                       '5200 of the Revised Statutes Total \n'
#                                       '                     Loans and '
#                                       'Extensions of Credit\n'
#                                       '\n'
#                                       '    (a)(1) The total loans and '
#                                       'extensions of credit by a national \n'
#                                       'banking association to a person '
#                                       'outstanding at one time and not fully \n'
#                                       'secured, as determined in a manner '
#                                       'consistent with paragraph (2) of this \n'
#                                       'subsection, by collateral having a '
#                                       'market value at least equal to the \n'
#                                       'amount of the loan or extension of '
#                                       'credit shall not exceed 15 per centum \n'
#                                       'of the unimpaired capital and '
#                                       'unimpaired surplus of the association.\n'
#                                       '    (2) The total loans and extensions '
#                                       'of credit by a national banking \n'
#                                       'association to a person outstanding at '
#                                       'one time and fully secured by \n'
#                                       'readily marketable collateral having a '
#                                       'market value, as determined by \n'
#                                       'reliable and continuously available '
#                                       'price quotations, at least equal to \n'
#                                       'the amount of the funds outstanding '
#                                       'shall not exceed 10 per centum of \n'
#                                       'the unimpaired capital and unimpaired '
#                                       'surplus of the association. This \n'
#                                       'limitation shall be separate from and '
#                                       'in addition to the limitations \n'
#                                       'contained in paragraph (1) of this '
#                                       'subsection.\n'
#                                       '\n'
#                                       '                               '
#                                       'Definitions\n'
#                                       '\n'
#                                       '    (b) For the purposes of this '
#                                       'section--\n'
#                                       '    (1) The term loans and extensions '
#                                       'of credit shall include all direct \n'
#                                       'or indirect advances of funds to a '
#                                       'person made on the basis of any \n'
#                                       'obligation of that person to repay the '
#                                       'funds or repayable from specific \n'
#                                       'property pledged by or on behalf of the '
#                                       'person, and to the extent \n'
#                                       'specified by the Comptroller of the '
#                                       'Currency, such term shall also \n'
#                                       'include any liability of a national '
#                                       'banking association to advance funds \n'
#                                       'to or on behalf of a person pursuant to '
#                                       'a contractual commitment; and\n'
#                                       '    (2) The term person shall include '
#                                       'an individual, sole \n'
#                                       'proprietorship, partnership, joint '
#                                       'venture, association, trust, estate, \n'
#                                       'business trust, corporation, sovereign '
#                                       'government, or agency, \n'
#                                       'instrumentality, or political '
#                                       'subdivision thereof, or any similar '
#                                       'entity \n'
#                                       'or organization.\n'
#                                       '\n'
#                                       '                               '
#                                       'Exceptions',
#                            'id': 10661.0,
#                            'postchunk': '(a)(1) The total loans and extensions '
#                                         'of credit by a national \n'
#                                         'banking association to a person '
#                                         'outstanding at one time and not '
#                                         'fully \n'
#                                         'secured, as determined in a manner '
#                                         'consistent with paragraph (2) of '
#                                         'this \n'
#                                         'subsection, by collateral having a '
#                                         'market value at least equal to the \n'
#                                         'amount of the loan or extension of '
#                                         'credit shall not exceed 15 per '
#                                         'centum \n'
#                                         'of the unimpaired capital and '
#                                         'unimpaired surplus of the '
#                                         'association.\n'
#                                         '    (2) The total loans and '
#                                         'extensions of credit by a national '
#                                         'banking \n'
#                                         'association to a person outstanding '
#                                         'at one time and fully secured by \n'
#                                         'readily marketable collateral having '
#                                         'a market value, as determined by \n'
#                                         'reliable and continuously available '
#                                         'price quotations, at least equal to \n'
#                                         'the amount of the funds outstanding '
#                                         'shall not exceed 10 per centum of \n'
#                                         'the unimpaired capital and unimpaired '
#                                         'surplus of the association. This \n'
#                                         'limitation shall be separate from and '
#                                         'in addition to the limitations \n'
#                                         'contained in paragraph (1) of this '
#                                         'subsection.\n'
#                                         '\n'
#                                         '                               '
#                                         'Definitions\n'
#                                         '\n'
#                                         '    (b) For the purposes of this '
#                                         'section--\n'
#                                         '    (1) The term loans and extensions '
#                                         'of credit shall include all direct \n'
#                                         'or indirect advances of funds to a '
#                                         'person made on the basis of any \n'
#                                         'obligation of that person to repay '
#                                         'the funds or repayable from '
#                                         'specific \n'
#                                         'property pledged by or on behalf of '
#                                         'the person, and to the extent \n'
#                                         'specified by the Comptroller of the '
#                                         'Currency, such term shall also \n'
#                                         'include any liability of a national '
#                                         'banking association to advance '
#                                         'funds \n'
#                                         'to or on behalf of a person pursuant '
#                                         'to a contractual commitment; and\n'
#                                         '    (2) The term person shall include '
#                                         'an individual, sole \n'
#                                         'proprietorship, partnership, joint '
#                                         'venture, association, trust, '
#                                         'estate, \n'
#                                         'business trust, corporation, '
#                                         'sovereign government, or agency, \n'
#                                         'instrumentality, or political '
#                                         'subdivision thereof, or any similar '
#                                         'entity \n'
#                                         'or organization.\n'
#                                         '\n'
#                                         '                               '
#                                         'Exceptions\n'
#                                         '\n'
#                                         '    (c) The limitations contained in '
#                                         'subsection (a) of this section \n'
#                                         'shall be subject to the following '
#                                         'exceptions:\n'
#                                         '    (1) Loans or extensions of credit '
#                                         'arising from the discount of \n'
#                                         'commercial or business paper '
#                                         'evidencing an obligation to the '
#                                         'person \n'
#                                         'negotiating it with recourse shall '
#                                         'not be subject to any limitation \n'
#                                         'based on capital and surplus.\n'
#                                         "    (2) The purchase of bankers' "
#                                         'acceptances of the kind described '
#                                         'in \n'
#                                         'section 372 of this title and issued '
#                                         'by other banks shall not be subject \n'
#                                         'to any limitation based on capital '
#                                         'and surplus.\n'
#                                         '    (3) Loans and extensions of '
#                                         'credit secured by bills of lading, \n'
#                                         'warehouse receipts, or similar '
#                                         'documents transferring or securing '
#                                         'title \n'
#                                         'to readily marketable staples shall '
#                                         'be subject to a limitation of 35 '
#                                         'per \n'
#                                         'centum of capital and surplus in '
#                                         'addition to the general limitations '
#                                         'if \n'
#                                         'the market value of the staples '
#                                         'securing each additional loan or \n'
#                                         'extension of credit at all times '
#                                         'equals or exceeds 115 per centum of '
#                                         'the \n'
#                                         'outstanding amount of such loan or '
#                                         'extension of credit. The staples \n'
#                                         'shall be fully covered by insurance '
#                                         'whenever it is customary to insure \n'
#                                         'such staples.\n'
#                                         '    (4) Loans or extensions of credit '
#                                         'secured by bonds, notes, \n'
#                                         'certificates of indebtedness, or '
#                                         'Treasury bills of the United States '
#                                         'or \n'
#                                         'by other such obligations fully '
#                                         'guaranteed as to principal and '
#                                         'interest \n'
#                                         'by the United States shall not be '
#                                         'subject to any limitation based on \n'
#                                         'capital and surplus.\n'
#                                         '    (5) Loans or extensions of credit '
#                                         'to or secured by unconditional \n'
#                                         'takeout commitments or guarantees of '
#                                         'any department, agency, bureau, \n'
#                                         'board, commission, or establishment '
#                                         'of the United States or any \n'
#                                         'corporation wholly owned directly or '
#                                         'indirectly by the United States \n'
#                                         'shall not be subject to any '
#                                         'limitation based on capital and '
#                                         'surplus.\n'
#                                         '    (6) Loans or extensions of credit '
#                                         'secured by a segregated deposit \n'
#                                         'account in the lending bank shall not '
#                                         'be subject to any limitation based \n'
#                                         'on capital and surplus.\n'
#                                         '    (7) Loans or extensions of credit '
#                                         'to any financial institution or to \n'
#                                         'any receiver, conservator, '
#                                         'superintendent of banks, or other '
#                                         'agent in \n'
#                                         'charge of the business and property '
#                                         'of such financial institution, when \n'
#                                         'such loans or extensions of credit '
#                                         'are approved by the Comptroller of \n'
#                                         'the Currency, shall not be subject to '
#                                         'any limitation based on capital \n'
#                                         'and surplus.\n'
#                                         '    (8)(A) Loans and extensions of '
#                                         'credit arising from the discount of \n'
#                                         'negotiable or nonnegotiable '
#                                         'installment consumer paper which '
#                                         'carries a \n'
#                                         'full recourse endorsement or '
#                                         'unconditional guarantee by the '
#                                         'person \n'
#                                         'transferring the paper shall be '
#                                         'subject under this section to a '
#                                         'maximum \n'
#                                         'limitation equal to 25 per centum of '
#                                         'such capital and surplus, \n'
#                                         'notwithstanding the collateral '
#                                         'requirements set forth in '
#                                         'subsection \n'
#                                         '(a)(2) of this section.\n'
#                                         "    (B) If the bank's files or the "
#                                         'knowledge of its officers of the \n'
#                                         'financial condition of each maker of '
#                                         'such consumer paper is reasonably \n'
#                                         'adequate, and an officer of the bank '
#                                         'designated for that purpose by the \n'
#                                         'board of directors of the bank '
#                                         'certifies in writing that the bank '
#                                         'is \n'
#                                         'relying primarily upon the '
#                                         'responsibility of each maker for '
#                                         'payment of\n'
#                                         '\n'
#                                         '[[Page 406]]',
#                            'prechunk': '[[Page 404]]\n'
#                                        '\n'
#                                        'of the board of directors of the bank '
#                                        'from making an extension of credit \n'
#                                        'to any company or other entity that is '
#                                        'covered by this part as a company \n'
#                                        'is not required to maintain any '
#                                        'records of the related interests of '
#                                        'the \n'
#                                        'insiders of the bank or its affiliates '
#                                        'or to inquire of borrowers \n'
#                                        'whether they are related interests of '
#                                        'the insiders of the bank or its \n'
#                                        'affiliates.\n'
#                                        '\n'
#                                        '\n'
#                                        '<R05>\n'
#                                        'Sec.  215.9  Disclosure of credit from '
#                                        'member banks to executive\n'
#                                        'officers and principal shareholders.\n'
#                                        '\n'
#                                        '    (a) Definitions. For the purposes '
#                                        'of this section, the following \n'
#                                        'definitions apply:\n'
#                                        '    (1) Principal shareholder of a '
#                                        'member bank means any person other \n'
#                                        'than an insured bank, or a foreign '
#                                        'bank as defined in 12 U.S.C. '
#                                        '3101(7), \n'
#                                        'that, directly or indirectly, owns, '
#                                        'controls, or has power to vote more \n'
#                                        'than 10 percent of any class of voting '
#                                        'securities of the member bank. \n'
#                                        'The term includes a person that '
#                                        'controls a principal shareholder '
#                                        '(e.g., \n'
#                                        'a person that controls a bank holding '
#                                        'company). Shares of a bank \n'
#                                        '(including a foreign bank), bank '
#                                        'holding company, savings and loan \n'
#                                        'holding company or other company owned '
#                                        'or controlled by a member of an \n'
#                                        "individual's immediate family are "
#                                        'presumed to be owned or controlled '
#                                        'by \n'
#                                        'the individual for the purposes of '
#                                        'determining principal shareholder \n'
#                                        'status.\n'
#                                        '    (2) Related interest means:\n'
#                                        '    (i) Any company controlled by a '
#                                        'person; or\n'
#                                        '    (ii) Any political or campaign '
#                                        'committee the funds or services of \n'
#                                        'which will benefit a person or that is '
#                                        'controlled by a person. For the \n'
#                                        'purpose of this section, a related '
#                                        'interest does not include a bank or '
#                                        'a \n'
#                                        'foreign bank (as defined in 12 U.S.C. '
#                                        '3101(7)).\n'
#                                        '    (b) Public disclosure. (1) Upon '
#                                        'receipt of a written request from \n'
#                                        'the public, a member bank shall make '
#                                        'available the names of each of its \n'
#                                        'executive officers and each of its '
#                                        'principal shareholders to whom, or '
#                                        'to \n'
#                                        'whose related interests, the member '
#                                        'bank had outstanding as of the end \n'
#                                        'of the latest previous quarter of the '
#                                        'year, an extension of credit that, \n'
#                                        'when aggregated with all other '
#                                        'outstanding extensions of credit at '
#                                        'such \n'
#                                        'time from the member bank to such '
#                                        'person and to all related interests '
#                                        'of \n'
#                                        'such person, equaled or exceeded 5 '
#                                        "percent of the member bank's capital \n"
#                                        'and unimpaired surplus or $500,000, '
#                                        'whichever amount is less. No \n'
#                                        'disclosure under this paragraph is '
#                                        'required if the aggregate amount of \n'
#                                        'all extensions of credit outstanding '
#                                        'at such time from the member bank \n'
#                                        'to the executive officer or principal '
#                                        'shareholder of the member bank and \n'
#                                        'to all related interests of such a '
#                                        'person does not exceed $25,000.\n'
#                                        '    (2) A member bank is not required '
#                                        'to disclose the specific amounts \n'
#                                        'of individual extensions of credit.\n'
#                                        '    (c) Maintaining records. Each '
#                                        'member bank shall maintain records '
#                                        'of \n'
#                                        'all requests for the information '
#                                        'described in paragraph (b) of this \n'
#                                        'section and the disposition of such '
#                                        'requests. These records may be \n'
#                                        'disposed of after two years from the '
#                                        'date of the request.\n'
#                                        '\n'
#                                        '[Reg. O, 59 FR 8837, Feb. 24, 1994; 59 '
#                                        'FR 37930, July 26, 1994. \n'
#                                        'Redesignated and amended at 71 FR '
#                                        '71474, Dec. 11, 2006, as amended at '
#                                        '76 \n'
#                                        'FR 56530, Sept. 13, 2011]\n'
#                                        '\n'
#                                        '\n'
#                                        '<R05>\n'
#                                        'Sec.  215.10  Reporting requirement '
#                                        'for credit secured by certain bank '
#                                        'stock.\n'
#                                        '\n'
#                                        '    Each executive officer or director '
#                                        'of a member bank the shares of \n'
#                                        'which are not publicly traded shall '
#                                        'report annually to the board of \n'
#                                        'directors of the member bank the '
#                                        'outstanding amount of any credit '
#                                        'that \n'
#                                        'was extended to the executive officer '
#                                        'or director and that is secured by \n'
#                                        'shares of the member bank.\n'
#                                        '\n'
#                                        '[Reg. O, 59 FR 8837, Feb. 24, 1994. '
#                                        'Redesignated at 71 FR 71474, Dec. \n'
#                                        '11, 2006]\n'
#                                        '\n'
#                                        '\n'
#                                        '<R05>\n'
#                                        'Sec.  215.11  Civil penalties.\n'
#                                        '\n'
#                                        '    Any member bank, or any officer, '
#                                        'director, employee, agent, or other \n'
#                                        'person participating in the conduct of '
#                                        'the affairs of the bank, that \n'
#                                        'violates any provision of this part '
#                                        '(other than Sec.  215.9) is subject \n'
#                                        'to civil penalties as specified in '
#                                        'section 29 of the Federal Reserve '
#                                        'Act \n'
#                                        '(12 U.S.C. 504).\n'
#                                        '\n'
#                                        '[Reg. O, 71 FR 71475, Dec. 11, 2006]\n'
#                                        '\n'
#                                        '\n'
#                                        '<R05>\n'
#                                        'Sec.  215.12  Application to savings '
#                                        'associations.\n'
#                                        '\n'
#                                        '    The requirements of this part '
#                                        'apply to savings associations, as \n'
#                                        'defined in 12 CFR 238.2(l) (including '
#                                        'any subsidiary of a savings \n'
#                                        'association), in the same\n'
#                                        '\n'
#                                        '[[Page 405]]\n'
#                                        '\n'
#                                        'manner and to the same extent as if '
#                                        'the savings association were a \n'
#                                        'member bank; provided that a savings '
#                                        "association's unimpaired capital \n"
#                                        'and unimpaired surplus will be '
#                                        'determined under regulatory capital '
#                                        'rules \n'
#                                        'applicable to that savings '
#                                        'association.\n'
#                                        '\n'
#                                        '[Reg. O, 76 FR 56530, Sept. 13, 2011]\n'
#                                        '\n'
#                                        '\n'
#                                        '<R05>\n'
#                                        ' Sec. Appendix to Part 215--Section '
#                                        '5200 of the Revised Statutes Total \n'
#                                        '                     Loans and '
#                                        'Extensions of Credit',
#                            'title': 'CFR-2024-title12-vol2.txt',
#                            'token_count': 754.0},
#               'score': 0.5996702,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': '10651',
#               'metadata': {'content': '[Reg. N, 27 FR 1719, Feb. 22, 1962]\n'
#                                       '\n'
#                                       '\n'
#                                       '<R05>\n'
#                                       'Sec.  214.6  Amendments.\n'
#                                       '\n'
#                                       '    The Board of Governors of the '
#                                       'Federal Reserve System reserves the \n'
#                                       'right, in its discretion, to alter, '
#                                       'amend or repeal these regulations \n'
#                                       'and to prescribe such additional '
#                                       'regulations, conditions, and \n'
#                                       'limitations as it may deem desirable, '
#                                       'respecting relationships and \n'
#                                       'transactions of any kind entered into '
#                                       'by any Federal Reserve Bank with \n'
#                                       'any foreign bank or banker or with any '
#                                       'group of foreign banks or bankers \n'
#                                       'or with any foreign State.\n'
#                                       '\n'
#                                       '[Reg. N, 8 FR 17290, Dec. 24, 1943. '
#                                       'Redesignated at 27 FR 1719, Feb. 22, \n'
#                                       '1962]\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       '<R03>\n'
#                                       'PART 215_LOANS TO EXECUTIVE OFFICERS, '
#                                       'DIRECTORS, AND PRINCIPAL\n'
#                                       'SHAREHOLDERS OF MEMBER BANKS '
#                                       '(REGULATION O)--Table of Contents\n'
#                                       '\n'
#                                       '\n'
#                                       '\n'
#                                       'Sec.\n'
#                                       '215.1 Authority, purpose, and scope.\n'
#                                       '215.2 Definitions.\n'
#                                       '215.3 Extension of credit.\n'
#                                       '215.4 General prohibitions.\n'
#                                       '215.5 Additional restrictions on loans '
#                                       'to executive officers of member \n'
#                                       '          banks.\n'
#                                       '215.6 Prohibition on knowingly '
#                                       'receiving unauthorized extension of \n'
#                                       '          credit.\n'
#                                       '215.7 Extensions of credit outstanding '
#                                       'on March 10, 1979.\n'
#                                       '215.8 Records of member banks.\n'
#                                       '215.9 Disclosure of credit from member '
#                                       'banks to executive officers and \n'
#                                       '          principal shareholders.\n'
#                                       '215.10 Reporting requirement for credit '
#                                       'secured by certain bank stock.\n'
#                                       '215.11 Civil penalties.\n'
#                                       '215.12 Application to savings '
#                                       'associations.\n'
#                                       '\n'
#                                       'Appendix to Part 215--Section 5200 of '
#                                       'the Revised Statutes Total Loans \n'
#                                       '          and Extensions of Credit\n'
#                                       '\n'
#                                       '    Authority: 12 U.S.C. 248(a), '
#                                       '375a(10), 375b(9) and (10), 1468, \n'
#                                       '1817(k), 5412; and Pub. L. 102-242, 105 '
#                                       'Stat. 2236 (1991) (12 U.S.C. \n'
#                                       '1811 note).\n'
#                                       '\n'
#                                       '    Source: Reg. O, 59 FR 8837, Feb. '
#                                       '24, 1994, unless otherwise noted.\n'
#                                       '\n'
#                                       '\n'
#                                       '<R05>\n'
#                                       'Sec.  215.1  Authority, purpose, and '
#                                       'scope.\n'
#                                       '\n'
#                                       '    (a) Authority. This part is issued '
#                                       'pursuant to sections 11(a), \n'
#                                       '22(g), and 22(h) of the Federal Reserve '
#                                       'Act (12 U.S.C. 248(a), 375a, and \n'
#                                       '375b), 12 U.S.C. 1817(k), section 306 '
#                                       'of the Federal Deposit Insurance \n'
#                                       'Corporation Improvement Act of 1991 '
#                                       '(Pub. L. 102-242, 105 Stat. 2236 \n'
#                                       "(1991)), section 11 of the Home Owners' "
#                                       'Loan Act (12 U.S.C. 1468), and \n'
#                                       'section 312(b)(2)(A) of the Dodd-Frank '
#                                       'Wall Street Reform and Consumer \n'
#                                       'Protection Act (12 U.S.C. 5412).\n'
#                                       '    (b) Purpose and scope. (1) This '
#                                       'part governs any extension of credit \n'
#                                       'made by a member bank to an executive '
#                                       'officer, director, or principal \n'
#                                       'shareholder of the member bank, of any '
#                                       'company of which the member bank \n'
#                                       'is a subsidiary, and of any other '
#                                       'subsidiary of that company.\n'
#                                       '    (2) This part also applies to any '
#                                       'extension of credit made by a \n'
#                                       'member bank to a company controlled by '
#                                       'such a person, or to a political \n'
#                                       'or campaign\n'
#                                       '\n'
#                                       '[[Page 396]]\n'
#                                       '\n'
#                                       'committee that benefits or is '
#                                       'controlled by such a person.\n'
#                                       '    (3) This part also implements the '
#                                       'reporting requirements of 12 \n'
#                                       'U.S.C. 1817(k) concerning extensions of '
#                                       'credit by a member bank to its \n'
#                                       'executive officers or principal '
#                                       'shareholders (or to the related \n'
#                                       'interests of such persons).\n'
#                                       '    (4) Extensions of credit made to an '
#                                       'executive officer, director, or \n'
#                                       'principal shareholder of a bank (or to '
#                                       'a related interest of such \n'
#                                       'person) by a correspondent bank also '
#                                       'are subject to restrictions set \n'
#                                       'forth in 12 U.S.C. 1972(2).\n'
#                                       '\n'
#                                       '[Reg. O, 71 FR 71474, Dec. 11, 2006, as '
#                                       'amended at 76 FR 56530, Sept. \n'
#                                       '13, 2011]\n'
#                                       '\n'
#                                       '\n'
#                                       '<R05>\n'
#                                       'Sec.  215.2  Definitions.',
#                            'id': 10651.0,
#                            'postchunk': '[[Page 396]]\n'
#                                         '\n'
#                                         'committee that benefits or is '
#                                         'controlled by such a person.\n'
#                                         '    (3) This part also implements the '
#                                         'reporting requirements of 12 \n'
#                                         'U.S.C. 1817(k) concerning extensions '
#                                         'of credit by a member bank to its \n'
#                                         'executive officers or principal '
#                                         'shareholders (or to the related \n'
#                                         'interests of such persons).\n'
#                                         '    (4) Extensions of credit made to '
#                                         'an executive officer, director, or \n'
#                                         'principal shareholder of a bank (or '
#                                         'to a related interest of such \n'
#                                         'person) by a correspondent bank also '
#                                         'are subject to restrictions set \n'
#                                         'forth in 12 U.S.C. 1972(2).\n'
#                                         '\n'
#                                         '[Reg. O, 71 FR 71474, Dec. 11, 2006, '
#                                         'as amended at 76 FR 56530, Sept. \n'
#                                         '13, 2011]\n'
#                                         '\n'
#                                         '\n'
#                                         '<R05>\n'
#                                         'Sec.  215.2  Definitions.\n'
#                                         '\n'
#                                         '    For purposes of this part, the '
#                                         'following definitions apply unless \n'
#                                         'otherwise specified:\n'
#                                         '    (a) Affiliate means any company '
#                                         'of which a member bank is a \n'
#                                         'subsidiary or any other subsidiary of '
#                                         'that company.\n'
#                                         '    (b) Company means any '
#                                         'corporation, partnership, trust '
#                                         '(business or \n'
#                                         'otherwise), association, joint '
#                                         'venture, pool syndicate, sole \n'
#                                         'proprietorship, unincorporated '
#                                         'organization, or any other form of \n'
#                                         'business entity not specifically '
#                                         'listed herein. However, the term '
#                                         'does \n'
#                                         'not include:\n'
#                                         '    (1) An insured depository '
#                                         'institution (as defined in 12 '
#                                         'U.S.C. \n'
#                                         '1813); or\n'
#                                         '    (2) A corporation the majority of '
#                                         'the shares of which are owned by \n'
#                                         'the United States or by any State.\n'
#                                         '    (c)(1) Control of a company or '
#                                         'bank means that a person directly '
#                                         'or \n'
#                                         'indirectly, or acting through or in '
#                                         'concert with one or more persons:\n'
#                                         '    (i) Owns, controls, or has the '
#                                         'power to vote 25 percent or more of \n'
#                                         'any class of voting securities of the '
#                                         'company or bank;\n'
#                                         '    (ii) Controls in any manner the '
#                                         'election of a majority of the \n'
#                                         'directors of the company or bank; or\n'
#                                         '    (iii) Has the power to exercise a '
#                                         'controlling influence over the \n'
#                                         'management or policies of the company '
#                                         'or bank.\n'
#                                         '    (2) A person is presumed to have '
#                                         'control, including the power to \n'
#                                         'exercise a controlling influence over '
#                                         'the management or policies, of a \n'
#                                         'company or bank if:\n'
#                                         '    (i) The person is:\n'
#                                         '    (A) An executive officer or '
#                                         'director of the company or bank; and\n'
#                                         '    (B) Directly or indirectly owns, '
# ...
#                                         'and requests for information.\n'
#                                         '\n'
#                                         '(3) Capital\n'
#                                         '(A) In general\n'
#                                         'The Board may not, by regulation, '
#                                         'guideline, order, or otherwise, '
#                                         'prescribe or impose any capital or '
#                                         'capital adequacy rules, guidelines, '
#                                         'standards, or requirements on any '
#                                         'functionally regulated subsidiary of '
#                                         'a bank holding company that—\n'
#                                         '\n'
#                                         '(i) is not a depository institution; '
#                                         'and\n'
#                                         '\n'
#                                         '(ii) is—\n'
#                                         '\n'
#                                         '(I) in compliance with the applicable '
#                                         'capital requirements of its Federal '
#                                         'regulatory authority (including the '
#                                         'Securities and Exchange Commission) '
#                                         'or State insurance authority;\n'
#                                         '\n'
#                                         '(II) properly registered as an '
#                                         'investment adviser under the '
#                                         'Investment Advisers Act of 1940 [15 '
#                                         'U.S.C. 80b–1 et seq.], or with any '
#                                         'State; or\n'
#                                         '\n'
#                                         '(III) is licensed as an insurance '
#                                         'agent with the appropriate State '
#                                         'insurance authority.\n'
#                                         '\n'
#                                         '(B) Rule of construction\n'
#                                         'Subparagraph (A) shall not be '
#                                         'construed as preventing the Board '
#                                         'from imposing capital or capital '
#                                         'adequacy rules, guidelines, '
#                                         'standards, or requirements with '
#                                         'respect to—\n'
#                                         '\n'
#                                         '(i) activities of a registered '
#                                         'investment adviser other than with '
#                                         'respect to investment advisory '
#                                         'activities or activities incidental '
#                                         'to investment advisory activities; '
#                                         'or\n'
#                                         '\n'
#                                         '(ii) activities of a licensed '
#                                         'insurance agent other than insurance '
#                                         'agency activities or activities '
#                                         'incidental to insurance agency '
#                                         'activities.\n'
#                                         '\n'
#                                         '(C) Limitations on indirect action\n'
#                                         'In developing, establishing, or '
#                                         'assessing bank holding company '
#                                         'capital or capital adequacy rules, '
#                                         'guidelines, standards, or '
#                                         'requirements for purposes of this '
#                                         'paragraph, the Board may not take '
#                                         'into account the activities, '
#                                         'operations, or investments of an '
#                                         'affiliated investment company '
#                                         'registered under the Investment '
#                                         'Company Act of 1940 [15 U.S.C. 80a–1 '
#                                         'et seq.], unless the investment '
#                                         'company is—\n'
#                                         '\n'
#                                         '(i) a bank holding company; or',
#                            'prechunk': 'Report to Congress on New Activities '
#                                        'of Financial Holding Companies\n'
#                                        'Pub. L. 106–102, title I, §103(d), '
#                                        'Nov. 12, 1999, 113 Stat. 1351, '
#                                        'provided that by the end of the 4-year '
#                                        'period beginning on Nov. 12, 1999, the '
#                                        'Board of Governors of the Federal '
#                                        'Reserve System and the Secretary of '
#                                        'the Treasury were to submit a joint '
#                                        'report to Congress containing a '
#                                        'summary of new activities, including '
#                                        'grandfathered commercial activities, '
#                                        'in which any financial holding company '
#                                        'is engaged pursuant to subsection '
#                                        '(k)(1) or (n) of this section.\n'
#                                        '\n'
#                                        'Consideration of Merchant Banking '
#                                        'Activities by Financial Subsidiaries\n'
#                                        'Pub. L. 106–102, title I, §122, Nov. '
#                                        '12, 1999, 113 Stat. 1381, provided '
#                                        'that: "After the end of the 5-year '
#                                        'period beginning on the date of the '
#                                        'enactment of the Gramm-Leach-Bliley '
#                                        'Act [Nov. 12, 1999], the Board of '
#                                        'Governors of the Federal Reserve '
#                                        'System and the Secretary of the '
#                                        'Treasury may, if appropriate, after '
#                                        'considering—\n'
#                                        '\n'
#                                        '"(1) the experience with the effects '
#                                        'of financial modernization under this '
#                                        'Act [see Tables for classification] '
#                                        'and merchant banking activities of '
#                                        'financial holding companies;\n'
#                                        '\n'
#                                        '"(2) the potential effects on '
#                                        'depository institutions and the '
#                                        'financial system of allowing merchant '
#                                        'banking activities in financial '
#                                        'subsidiaries; and\n'
#                                        '\n'
#                                        '"(3) other relevant facts;\n'
#                                        '\n'
#                                        'jointly adopt rules that permit '
#                                        'financial subsidiaries to engage in '
#                                        'merchant banking activities described '
#                                        'in section 4(k)(4)(H) of the Bank '
#                                        'Holding Company Act of 1956 [12 U.S.C. '
#                                        '1843(k)(4)(H)], under such terms and '
#                                        'conditions as the Board of Governors '
#                                        'of the Federal Reserve System and the '
#                                        'Secretary of the Treasury jointly '
#                                        'determine to be appropriate."\n'
#                                        '\n'
#                                        'Modification of Prior Approvals\n'
#                                        'Pub. L. 101–73, title VI, §601(b), '
#                                        'Aug. 9, 1989, 103 Stat. 409, provided '
#                                        'that: "If the Board of Governors of '
#                                        'the Federal Reserve System, in '
#                                        'approving an application by a bank '
#                                        'holding company to acquire a savings '
#                                        'association, imposed any restriction '
#                                        'that would have been prohibited under '
#                                        'section 4(i)(2) of the Bank Holding '
#                                        'Company Act of 1956 [12 U.S.C. '
#                                        '1843(i)(2)] (as added by subsection '
#                                        '(a) of this section) if that section '
#                                        'had been in effect when the '
#                                        'application was approved, the Board '
#                                        'shall modify that approval in a manner '
#                                        'consistent with that section."\n'
#                                        '\n'
#                                        'Extension of Emergency Acquisition and '
#                                        'Net Worth Guarantee Provisions of Pub. '
#                                        'L. 97–320\n'
#                                        'No amendment made by section 141(a) of '
#                                        'Pub. L. 97–320, set out as a note '
#                                        'under section 1464 of this title, as '
#                                        'in effect before Aug. 10, 1987, to any '
#                                        'other provision of law to be deemed to '
#                                        'have taken effect before such date and '
#                                        'any such provision of law to be in '
#                                        'effect as if no such amendment had '
#                                        'been made before such date, see '
#                                        'section 509(c) of Pub. L. 100–86, set '
#                                        'out as a note under section 1464 of '
#                                        'this title.\n'
#                                        '\n'
#                                        'No amendment made by section 141(a) of '
#                                        'Pub. L. 97–320, set out as a note '
#                                        'under section 1464 of this title, as '
#                                        'in effect on the day before Oct. 8, '
#                                        '1986, to any other provision of law to '
#                                        'be deemed to have taken effect before '
#                                        'such date and any such provision of '
#                                        'law to be in effect as if no such '
#                                        'amendment had taken effect before such '
#                                        'date, see section 1(c) of Pub. L. '
#                                        '99–452, set out as a note under '
#                                        'section 1464 of this title.\n'
#                                        '\n'
#                                        'Section 141(a) of Pub. L. 97–320, set '
#                                        'out as a note under section 1464 of '
#                                        'this title, as in effect on the day '
#                                        'after Aug. 27, 1986, applicable as if '
#                                        'included in Pub. L. 97–320 on Oct. 15, '
#                                        '1982, with no amendment made by such '
#                                        'section to any other provision of law '
#                                        'to be deemed to have taken effect '
#                                        'before Aug. 27, 1986, and any such '
#                                        'provision of law to be in effect as if '
#                                        'no such amendment had taken effect '
#                                        'before Aug. 27, 1986, see section 1(c) '
#                                        'of Pub. L. 99–400, set out as a note '
#                                        'under section 1464 of this title.\n'
#                                        '\n'
#                                        'Bank Export Services\n'
#                                        'Pub. L. 97–290, title II, §202, Oct. '
#                                        '8, 1982, 96 Stat. 1235, provided that: '
#                                        '"The Congress hereby declares that it '
#                                        'is the purpose of this title [enacting '
#                                        'section 635a–4 of this title, amending '
#                                        'sections 372 and 1843 of this title, '
#                                        'and enacting provisions set out as '
#                                        'notes under section 1843 of this '
#                                        'title] to provide for meaningful and '
#                                        'effective participation by bank '
#                                        "holding companies, bankers' banks, and "
#                                        'Edge Act [12 U.S.C. 611 et seq.] '
#                                        'corporations, in the financing and '
#                                        'development of export trading '
#                                        'companies in the United States. In '
#                                        'furtherance of such purpose, the '
#                                        'Congress intends that, in implementing '
#                                        'its authority under section 4(c)(14) '
#                                        'of the Bank Holding Company Act of '
#                                        '1956 [subsec. (c)(14) of this section] '
#                                        'the Board of Governors of the Federal '
#                                        'Reserve System should pursue '
#                                        'regulatory policies that—\n'
#                                        '\n'
#                                        '"(1) provide for the establishment of '
#                                        'export trading companies with powers '
#                                        'sufficiently broad to enable them to '
#                                        'complete with similar foreign-owned '
#                                        'institutions in the United States and '
#                                        'abroad;',
#                            'title': 'U.S.C. Title 12 - BANKS AND BANKING.txt',
#                            'token_count': 1170.0},
#               'score': 0.5204428,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 11}}

# %%
response_context = ''
for r in res.matches:
    r["matches"]["metadata"]

# %%
res.matches[0]
# Out:
# {'id': '10661',
#  'metadata': {'content': 'Each executive officer or director of a member bank '
#                          'the shares of \n'
#                          'which are not publicly traded shall report annually '
#                          'to the board of \n'
#                          'directors of the member bank the outstanding amount '
#                          'of any credit that \n'
#                          'was extended to the executive officer or director '
#                          'and that is secured by \n'
#                          'shares of the member bank.\n'
#                          '\n'
#                          '[Reg. O, 59 FR 8837, Feb. 24, 1994. Redesignated at '
#                          '71 FR 71474, Dec. \n'
#                          '11, 2006]\n'
#                          '\n'
#                          '\n'
#                          '<R05>\n'
#                          'Sec.  215.11  Civil penalties.\n'
#                          '\n'
#                          '    Any member bank, or any officer, director, '
#                          'employee, agent, or other \n'
#                          'person participating in the conduct of the affairs '
#                          'of the bank, that \n'
#                          'violates any provision of this part (other than '
#                          'Sec.  215.9) is subject \n'
#                          'to civil penalties as specified in section 29 of the '
#                          'Federal Reserve Act \n'
#                          '(12 U.S.C. 504).\n'
#                          '\n'
#                          '[Reg. O, 71 FR 71475, Dec. 11, 2006]\n'
#                          '\n'
#                          '\n'
#                          '<R05>\n'
#                          'Sec.  215.12  Application to savings associations.\n'
#                          '\n'
#                          '    The requirements of this part apply to savings '
#                          'associations, as \n'
#                          'defined in 12 CFR 238.2(l) (including any subsidiary '
#                          'of a savings \n'
#                          'association), in the same\n'
#                          '\n'
#                          '[[Page 405]]\n'
#                          '\n'
#                          'manner and to the same extent as if the savings '
#                          'association were a \n'
#                          "member bank; provided that a savings association's "
#                          'unimpaired capital \n'
#                          'and unimpaired surplus will be determined under '
#                          'regulatory capital rules \n'
#                          'applicable to that savings association.\n'
#                          '\n'
#                          '[Reg. O, 76 FR 56530, Sept. 13, 2011]\n'
#                          '\n'
#                          '\n'
#                          '<R05>\n'
#                          ' Sec. Appendix to Part 215--Section 5200 of the '
#                          'Revised Statutes Total \n'
#                          '                     Loans and Extensions of Credit\n'
#                          '\n'
#                          '    (a)(1) The total loans and extensions of credit '
#                          'by a national \n'
#                          'banking association to a person outstanding at one '
#                          'time and not fully \n'
#                          'secured, as determined in a manner consistent with '
#                          'paragraph (2) of this \n'
#                          'subsection, by collateral having a market value at '
#                          'least equal to the \n'
#                          'amount of the loan or extension of credit shall not '
#                          'exceed 15 per centum \n'
#                          'of the unimpaired capital and unimpaired surplus of '
#                          'the association.\n'
#                          '    (2) The total loans and extensions of credit by '
#                          'a national banking \n'
#                          'association to a person outstanding at one time and '
#                          'fully secured by \n'
#                          'readily marketable collateral having a market value, '
#                          'as determined by \n'
#                          'reliable and continuously available price '
#                          'quotations, at least equal to \n'
#                          'the amount of the funds outstanding shall not exceed '
#                          '10 per centum of \n'
#                          'the unimpaired capital and unimpaired surplus of the '
#                          'association. This \n'
#                          'limitation shall be separate from and in addition to '
#                          'the limitations \n'
#                          'contained in paragraph (1) of this subsection.\n'
#                          '\n'
#                          '                               Definitions\n'
#                          '\n'
#                          '    (b) For the purposes of this section--\n'
#                          '    (1) The term loans and extensions of credit '
#                          'shall include all direct \n'
#                          'or indirect advances of funds to a person made on '
#                          'the basis of any \n'
#                          'obligation of that person to repay the funds or '
#                          'repayable from specific \n'
#                          'property pledged by or on behalf of the person, and '
#                          'to the extent \n'
#                          'specified by the Comptroller of the Currency, such '
#                          'term shall also \n'
#                          'include any liability of a national banking '
#                          'association to advance funds \n'
#                          'to or on behalf of a person pursuant to a '
#                          'contractual commitment; and\n'
#                          '    (2) The term person shall include an individual, '
#                          'sole \n'
#                          'proprietorship, partnership, joint venture, '
#                          'association, trust, estate, \n'
#                          'business trust, corporation, sovereign government, '
#                          'or agency, \n'
#                          'instrumentality, or political subdivision thereof, '
#                          'or any similar entity \n'
#                          'or organization.\n'
#                          '\n'
#                          '                               Exceptions',
#               'id': 10661.0,
#               'postchunk': '(a)(1) The total loans and extensions of credit by '
#                            'a national \n'
#                            'banking association to a person outstanding at one '
#                            'time and not fully \n'
#                            'secured, as determined in a manner consistent with '
#                            'paragraph (2) of this \n'
#                            'subsection, by collateral having a market value at '
#                            'least equal to the \n'
#                            'amount of the loan or extension of credit shall '
#                            'not exceed 15 per centum \n'
#                            'of the unimpaired capital and unimpaired surplus '
#                            'of the association.\n'
#                            '    (2) The total loans and extensions of credit '
#                            'by a national banking \n'
#                            'association to a person outstanding at one time '
#                            'and fully secured by \n'
#                            'readily marketable collateral having a market '
#                            'value, as determined by \n'
#                            'reliable and continuously available price '
#                            'quotations, at least equal to \n'
#                            'the amount of the funds outstanding shall not '
#                            'exceed 10 per centum of \n'
#                            'the unimpaired capital and unimpaired surplus of '
#                            'the association. This \n'
#                            'limitation shall be separate from and in addition '
#                            'to the limitations \n'
#                            'contained in paragraph (1) of this subsection.\n'
#                            '\n'
#                            '                               Definitions\n'
#                            '\n'
#                            '    (b) For the purposes of this section--\n'
#                            '    (1) The term loans and extensions of credit '
#                            'shall include all direct \n'
#                            'or indirect advances of funds to a person made on '
#                            'the basis of any \n'
#                            'obligation of that person to repay the funds or '
#                            'repayable from specific \n'
#                            'property pledged by or on behalf of the person, '
#                            'and to the extent \n'
#                            'specified by the Comptroller of the Currency, such '
#                            'term shall also \n'
#                            'include any liability of a national banking '
#                            'association to advance funds \n'
#                            'to or on behalf of a person pursuant to a '
#                            'contractual commitment; and\n'
#                            '    (2) The term person shall include an '
#                            'individual, sole \n'
#                            'proprietorship, partnership, joint venture, '
#                            'association, trust, estate, \n'
#                            'business trust, corporation, sovereign government, '
#                            'or agency, \n'
#                            'instrumentality, or political subdivision thereof, '
#                            'or any similar entity \n'
#                            'or organization.\n'
#                            '\n'
#                            '                               Exceptions\n'
#                            '\n'
#                            '    (c) The limitations contained in subsection '
#                            '(a) of this section \n'
#                            'shall be subject to the following exceptions:\n'
#                            '    (1) Loans or extensions of credit arising from '
#                            'the discount of \n'
#                            'commercial or business paper evidencing an '
#                            'obligation to the person \n'
#                            'negotiating it with recourse shall not be subject '
#                            'to any limitation \n'
#                            'based on capital and surplus.\n'
#                            "    (2) The purchase of bankers' acceptances of "
#                            'the kind described in \n'
#                            'section 372 of this title and issued by other '
#                            'banks shall not be subject \n'
#                            'to any limitation based on capital and surplus.\n'
#                            '    (3) Loans and extensions of credit secured by '
#                            'bills of lading, \n'
#                            'warehouse receipts, or similar documents '
#                            'transferring or securing title \n'
#                            'to readily marketable staples shall be subject to '
#                            'a limitation of 35 per \n'
#                            'centum of capital and surplus in addition to the '
#                            'general limitations if \n'
#                            'the market value of the staples securing each '
#                            'additional loan or \n'
#                            'extension of credit at all times equals or exceeds '
#                            '115 per centum of the \n'
#                            'outstanding amount of such loan or extension of '
#                            'credit. The staples \n'
#                            'shall be fully covered by insurance whenever it is '
#                            'customary to insure \n'
#                            'such staples.\n'
#                            '    (4) Loans or extensions of credit secured by '
#                            'bonds, notes, \n'
#                            'certificates of indebtedness, or Treasury bills of '
#                            'the United States or \n'
#                            'by other such obligations fully guaranteed as to '
#                            'principal and interest \n'
#                            'by the United States shall not be subject to any '
#                            'limitation based on \n'
#                            'capital and surplus.\n'
#                            '    (5) Loans or extensions of credit to or '
#                            'secured by unconditional \n'
#                            'takeout commitments or guarantees of any '
#                            'department, agency, bureau, \n'
#                            'board, commission, or establishment of the United '
#                            'States or any \n'
#                            'corporation wholly owned directly or indirectly by '
#                            'the United States \n'
#                            'shall not be subject to any limitation based on '
#                            'capital and surplus.\n'
#                            '    (6) Loans or extensions of credit secured by a '
#                            'segregated deposit \n'
#                            'account in the lending bank shall not be subject '
#                            'to any limitation based \n'
#                            'on capital and surplus.\n'
#                            '    (7) Loans or extensions of credit to any '
#                            'financial institution or to \n'
#                            'any receiver, conservator, superintendent of '
#                            'banks, or other agent in \n'
#                            'charge of the business and property of such '
#                            'financial institution, when \n'
#                            'such loans or extensions of credit are approved by '
#                            'the Comptroller of \n'
#                            'the Currency, shall not be subject to any '
#                            'limitation based on capital \n'
#                            'and surplus.\n'
#                            '    (8)(A) Loans and extensions of credit arising '
#                            'from the discount of \n'
#                            'negotiable or nonnegotiable installment consumer '
#                            'paper which carries a \n'
#                            'full recourse endorsement or unconditional '
#                            'guarantee by the person \n'
#                            'transferring the paper shall be subject under this '
#                            'section to a maximum \n'
#                            'limitation equal to 25 per centum of such capital '
#                            'and surplus, \n'
#                            'notwithstanding the collateral requirements set '
#                            'forth in subsection \n'
#                            '(a)(2) of this section.\n'
#                            "    (B) If the bank's files or the knowledge of "
#                            'its officers of the \n'
#                            'financial condition of each maker of such consumer '
#                            'paper is reasonably \n'
#                            'adequate, and an officer of the bank designated '
#                            'for that purpose by the \n'
#                            'board of directors of the bank certifies in '
#                            'writing that the bank is \n'
#                            'relying primarily upon the responsibility of each '
#                            'maker for payment of\n'
#                            '\n'
#                            '[[Page 406]]',
#               'prechunk': '[[Page 404]]\n'
#                           '\n'
#                           'of the board of directors of the bank from making '
#                           'an extension of credit \n'
#                           'to any company or other entity that is covered by '
#                           'this part as a company \n'
#                           'is not required to maintain any records of the '
#                           'related interests of the \n'
#                           'insiders of the bank or its affiliates or to '
#                           'inquire of borrowers \n'
#                           'whether they are related interests of the insiders '
#                           'of the bank or its \n'
#                           'affiliates.\n'
#                           '\n'
#                           '\n'
#                           '<R05>\n'
#                           'Sec.  215.9  Disclosure of credit from member banks '
#                           'to executive\n'
#                           'officers and principal shareholders.\n'
#                           '\n'
#                           '    (a) Definitions. For the purposes of this '
#                           'section, the following \n'
#                           'definitions apply:\n'
#                           '    (1) Principal shareholder of a member bank '
#                           'means any person other \n'
#                           'than an insured bank, or a foreign bank as defined '
#                           'in 12 U.S.C. 3101(7), \n'
#                           'that, directly or indirectly, owns, controls, or '
#                           'has power to vote more \n'
#                           'than 10 percent of any class of voting securities '
#                           'of the member bank. \n'
#                           'The term includes a person that controls a '
#                           'principal shareholder (e.g., \n'
#                           'a person that controls a bank holding company). '
#                           'Shares of a bank \n'
#                           '(including a foreign bank), bank holding company, '
#                           'savings and loan \n'
#                           'holding company or other company owned or '
#                           'controlled by a member of an \n'
#                           "individual's immediate family are presumed to be "
#                           'owned or controlled by \n'
#                           'the individual for the purposes of determining '
#                           'principal shareholder \n'
#                           'status.\n'
#                           '    (2) Related interest means:\n'
#                           '    (i) Any company controlled by a person; or\n'
#                           '    (ii) Any political or campaign committee the '
#                           'funds or services of \n'
#                           'which will benefit a person or that is controlled '
#                           'by a person. For the \n'
#                           'purpose of this section, a related interest does '
#                           'not include a bank or a \n'
#                           'foreign bank (as defined in 12 U.S.C. 3101(7)).\n'
#                           '    (b) Public disclosure. (1) Upon receipt of a '
#                           'written request from \n'
#                           'the public, a member bank shall make available the '
#                           'names of each of its \n'
#                           'executive officers and each of its principal '
#                           'shareholders to whom, or to \n'
#                           'whose related interests, the member bank had '
#                           'outstanding as of the end \n'
#                           'of the latest previous quarter of the year, an '
#                           'extension of credit that, \n'
#                           'when aggregated with all other outstanding '
#                           'extensions of credit at such \n'
#                           'time from the member bank to such person and to all '
#                           'related interests of \n'
#                           'such person, equaled or exceeded 5 percent of the '
#                           "member bank's capital \n"
#                           'and unimpaired surplus or $500,000, whichever '
#                           'amount is less. No \n'
#                           'disclosure under this paragraph is required if the '
#                           'aggregate amount of \n'
#                           'all extensions of credit outstanding at such time '
#                           'from the member bank \n'
#                           'to the executive officer or principal shareholder '
#                           'of the member bank and \n'
#                           'to all related interests of such a person does not '
#                           'exceed $25,000.\n'
#                           '    (2) A member bank is not required to disclose '
#                           'the specific amounts \n'
#                           'of individual extensions of credit.\n'
#                           '    (c) Maintaining records. Each member bank shall '
#                           'maintain records of \n'
#                           'all requests for the information described in '
#                           'paragraph (b) of this \n'
#                           'section and the disposition of such requests. These '
#                           'records may be \n'
#                           'disposed of after two years from the date of the '
#                           'request.\n'
#                           '\n'
#                           '[Reg. O, 59 FR 8837, Feb. 24, 1994; 59 FR 37930, '
#                           'July 26, 1994. \n'
#                           'Redesignated and amended at 71 FR 71474, Dec. 11, '
#                           '2006, as amended at 76 \n'
#                           'FR 56530, Sept. 13, 2011]\n'
#                           '\n'
#                           '\n'
#                           '<R05>\n'
#                           'Sec.  215.10  Reporting requirement for credit '
#                           'secured by certain bank stock.\n'
#                           '\n'
#                           '    Each executive officer or director of a member '
#                           'bank the shares of \n'
#                           'which are not publicly traded shall report annually '
#                           'to the board of \n'
#                           'directors of the member bank the outstanding amount '
#                           'of any credit that \n'
#                           'was extended to the executive officer or director '
#                           'and that is secured by \n'
#                           'shares of the member bank.\n'
#                           '\n'
#                           '[Reg. O, 59 FR 8837, Feb. 24, 1994. Redesignated at '
#                           '71 FR 71474, Dec. \n'
#                           '11, 2006]\n'
#                           '\n'
#                           '\n'
#                           '<R05>\n'
#                           'Sec.  215.11  Civil penalties.\n'
#                           '\n'
#                           '    Any member bank, or any officer, director, '
#                           'employee, agent, or other \n'
#                           'person participating in the conduct of the affairs '
#                           'of the bank, that \n'
#                           'violates any provision of this part (other than '
#                           'Sec.  215.9) is subject \n'
#                           'to civil penalties as specified in section 29 of '
#                           'the Federal Reserve Act \n'
#                           '(12 U.S.C. 504).\n'
#                           '\n'
#                           '[Reg. O, 71 FR 71475, Dec. 11, 2006]\n'
#                           '\n'
#                           '\n'
#                           '<R05>\n'
#                           'Sec.  215.12  Application to savings associations.\n'
#                           '\n'
#                           '    The requirements of this part apply to savings '
#                           'associations, as \n'
#                           'defined in 12 CFR 238.2(l) (including any '
#                           'subsidiary of a savings \n'
#                           'association), in the same\n'
#                           '\n'
#                           '[[Page 405]]\n'
#                           '\n'
#                           'manner and to the same extent as if the savings '
#                           'association were a \n'
#                           "member bank; provided that a savings association's "
#                           'unimpaired capital \n'
#                           'and unimpaired surplus will be determined under '
#                           'regulatory capital rules \n'
#                           'applicable to that savings association.\n'
#                           '\n'
#                           '[Reg. O, 76 FR 56530, Sept. 13, 2011]\n'
#                           '\n'
#                           '\n'
#                           '<R05>\n'
#                           ' Sec. Appendix to Part 215--Section 5200 of the '
#                           'Revised Statutes Total \n'
#                           '                     Loans and Extensions of Credit',
#               'title': 'CFR-2024-title12-vol2.txt',
#               'token_count': 754.0},
#  'score': 0.5997683,
#  'sparse_values': {'indices': [], 'values': []},
#  'values': []}

# %%
c = sorted(res.matches, key=lambda chunk: int(chunk['id']))
print(len(c))
# Out:
# 20

# %%
for i in c:
    print(i["id"], i["score"])
# Out:
# 2167 0.55118847
# 2300 0.5293496
# 2357 0.5204428
# 2799 0.5463193
# 2800 0.52279943
# 4089 0.5283464
# 5199 0.5328881
# 7591 0.52971715
# 8801 0.53396064
# 8802 0.55762064
# 10650 0.55030704
# 10651 0.59523314
# 10652 0.5306656
# 10659 0.5417333
# 10660 0.5926206
# 10661 0.5996702
# 12156 0.5214681
# 12704 0.5289556
# 13165 0.5371414
# 13166 0.5424339

# %%
chunk_list = []
for r in res.matches:
    chunk_list.append(r["metadata"]["prechunk"])
    chunk_list.append(r["metadata"]["content"])
    chunk_list.append(r["metadata"]["postchunk"])
unique_chunks = list(set(chunk_list))
print("Total Number of Chunks: ", len(chunk_list))
question_context = " ".join(unique_chunks)
print("Character Length: ", len(question_context))
print("Token Size: ", count_tokens_gpt4(question_context))
# Out:
# Total Number of Chunks:  120
# Character Length:  438527
# Token Size:  97279

# %%
developer_prompt = '''
# **Refined Prompt: Regulatory Requirement Extraction & Formatting**

## **Instructions**
Your task is to extract and format **explicit business requirements** from the given regulatory text to answer the user questions.

---

## **Regulatory Text**
{}

## **Output Format**
Provide the extracted requirements in a **CSV-parsable table** with the following structure:

| **Business Requirement** |
|----------------------------------------------------|
| [Extracted requirement 1] |
| [Extracted requirement 2] |
| ... |

- Each row must contain a **single** regulatory requirement.
- Maintain **verbatim wording** from the regulation—**do not paraphrase or summarize**.

---

## **Extraction Guidelines**
1. **Comprehensive Coverage**: Extract **all** explicit business requirements present in the regulation.
2. **Accuracy**: Use the **exact** wording from the regulatory text.
3. **Structural Integrity**: Ensure extracted text is **clearly formatted** and **CSV-compatible**.
4. **Thorough Review**: Carefully analyze the entire regulatory text to avoid omissions.

---

## **Additional Notes**
- If a requirement is ambiguous, **extract the most explicit portion** while keeping it verbatim.
- Exclude any **non-requirement** statements (e.g., general guidance, definitions, or contextual explanations).

'''.format(question_context)

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "developer", "content": developer_prompt},
    {"role": "user", "content": query}
  ]
)
display(Markdown(completion.choices[0].message.content))
# Out:
# | **Business Requirement** |
# |----------------------------------------------------|
# | No member bank may extend credit to any insider of the bank or insider of its affiliates unless the extension of credit is made on substantially the same terms as, and following credit underwriting procedures that are not less stringent than, those prevailing at the time for comparable transactions by the bank with other persons that are not covered by this part and who are not employed by the bank. |
# | A member bank may not extend credit to any insider of the bank or insider of its affiliates in an amount that, when aggregated with the amount of all other extensions of credit to that person and all related interests of that person, exceeds the higher of $25,000 or 5 percent of the member bank's unimpaired capital and unimpaired surplus, unless the extension of credit has been approved in advance by a majority of the entire board of directors of that bank and the interested party has abstained from participating directly or indirectly in the voting. |
# | In no event may a member bank extend credit to any insider of the bank or insider of its affiliates in an amount that, when aggregated with all other extensions of credit to that person, and all related interests of that person, exceeds $500,000, except by complying with the requirements for board approval. |
# | No member bank may extend credit to any insider of the bank or insider of its affiliates in an amount that, when aggregated with the amount of all other extensions of credit by the member bank to that person and to all related interests of that person, exceeds the lending limit of the member bank. |
# | A member bank may not extend credit to any insider of the bank or insider of its affiliates unless the extension of credit is in an amount that, when aggregated with the amount of all outstanding extensions of credit by that bank to all such insiders, does not exceed the bank's unimpaired capital and unimpaired surplus. |
# | The prohibition on paying overdrafts applies to an account of an executive officer or director of the bank or executive officer or director of its affiliates unless the payment of funds is made in accordance with a written, preauthorized, interest-bearing extension of credit plan that specifies a method of repayment or a written, preauthorized transfer of funds from another account of the account holder at the bank. |
# | No member bank may pay an overdraft of an executive officer or director of the bank or executive officer or director of its affiliates on an account at the bank, unless the payment of funds is made in accordance with a written, preauthorized, interest-bearing extension of credit plan that specifies a method of repayment or a written, preauthorized transfer of funds from another account of the account holder at the bank. |
# | No executive officer, director, or principal shareholder of a member bank or any of its affiliates shall knowingly receive from a member bank, directly or indirectly, any extension of credit not authorized under this section. |
# | Any extension of credit that was outstanding on March 10, 1979, and that would violate the lending limits established under Regulation O if made on or after March 10, 1979, shall be reduced in amount by March 10, 1980, to comply with the lending limit. |
# | Each member bank shall maintain records necessary for compliance with the requirements of this part. |
# | Executive officers or directors of member banks with shares not publicly traded shall report annually to the board of directors of the member bank the outstanding amount of any credit that was extended to them and that is secured by shares of the member bank. |
# | Any member bank, or any officer, director, employee, agent, or other person participating in the conduct of the affairs of the bank, that violates any provision of this part (other than the disclosure requirements) is subject to civil penalties as specified in section 29 of the Federal Reserve Act. |
